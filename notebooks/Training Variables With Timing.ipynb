# %% [markdown]
# What variables should be used for training. We look at the performance of the default training vs the training with each variable removed. If the performance improves when we remove a variable, we know that variable is making the training worse. Further, by looking at the change in performance we can rank the variables to first order.

# %% [markdown]
# # Initalization

# %%
from bdt_training_scikit_tools import load_trimmed_sample, \
    test_train_samples, prep_samples, default_training, calc_performance, get_fraction_of_events, \
    default_training_variable_list
import matplotlib.pyplot as plt
plt.rc('font', size=14)
from matplotlib.colors import LogNorm
import pandas as pd
import numpy as np
import multiprocessing as mp
import itertools

# %% [markdown]
# # Load Data Samples

# %%
all_events_all = load_trimmed_sample("133")

# %%
all_events = get_fraction_of_events(all_events_all, 250000)
print ([len(e.index) for e in all_events])
# Out:
# [249223, 248728, 248506]

# %%
plt.plot(all_events[2].mc_Lz)

# %% [markdown]
# # Determine Full Variable List
# We have to determine what variable list we want to start with before we start removing them according to their performance. Reasons for removal:
#
# - Weight variables are MC only things
# - Variables that have nothing to do with phyisics (like run #)
# - DR to closest track because it is used later in the analysis
# - JetPhi because physics *shouldn't* depend on that

# %%
all_events_all[0].columns
# Out:
# Index(['RunNumber', 'Weight', 'WeightMCEvent', 'WeightXSection',
#        'WeightFlatten', 'mc_Lxy', 'mc_Lz', 'MHTOverHT', 'JetPt', 'JetPhi',
#        'CalRatio', 'JetEta', 'NTracks', 'SumPtOfAllTracks', 'MaxTrackPt',
#        'EventNumber', 'JetET', 'JetWidth', 'JetDRTo2GeVTrack', 'EnergyDensity',
#        'HadronicLayer1Fraction', 'JetLat', 'JetLong', 'FirstClusterRadius',
#        'NumberOfClusters', 'ShowerCenter', 'BIBDeltaTimingM',
#        'BIBDeltaTimingP', 'FirstCellTiming', 'InteractionsPerCrossing',
#        'RPredictedLxy', 'RPredictedLz', 'PredictedLxy', 'PredictedLz',
#        'PredictedLxyHighEta', 'PredictedLxyLowEta', 'PredictedLzHighEta',
#        'PredictedLzLowEta'],
#       dtype='object')

# %%
variable_list = set(all_events_all[0].columns) - set(['RunNumber', 'Weight', 'WeightMCEvent', 'WeightXSection', 'WeightFlatten', 'mc_Lxy', 'mc_Lz', 'MHTOverHT', 'JetPhi', 'EventNumber', 'InteractionsPerCrossing', 'JetDRTo2GeVTrack', 'JetET'])

# Remove badly modeled items
variable_list = variable_list - set(['NumberOfClusters'])

variable_list
# Out:
# {'BIBDeltaTimingM',
#  'BIBDeltaTimingP',
#  'CalRatio',
#  'EnergyDensity',
#  'FirstCellTiming',
#  'FirstClusterRadius',
#  'HadronicLayer1Fraction',
#  'JetEta',
#  'JetLat',
#  'JetLong',
#  'JetPt',
#  'JetWidth',
#  'MaxTrackPt',
#  'NTracks',
#  'PredictedLxy',
#  'PredictedLxyHighEta',
#  'PredictedLxyLowEta',
#  'PredictedLz',
#  'PredictedLzHighEta',
#  'PredictedLzLowEta',
#  'RPredictedLxy',
#  'RPredictedLz',
#  'ShowerCenter',
#  'SumPtOfAllTracks'}

# %% [markdown]
# # Drop First Variable

# %%
# %%writefile get_training_performance.py
from bdt_training_scikit_tools import load_default_samples, default_training_variable_list, \
    test_train_samples, prep_samples, default_training, calc_performance
    
def do_training (vlist):
    all_events, training_list = vlist
    return get_training_performance (all_events, training_list)
    
def get_training_performance (all_events, training_list):
    '''Run a training with the set of varaibles given. Return a performance table.'''
    
    # Split into testing and training samples
    train, test = test_train_samples(all_events)
        
    # Prep samples for training
    all_events, all_events_class, training_weight, evaluation_weight = prep_samples(train[0], train[1], train[2], training_variable_list=training_list)
    
    # Run training
    bdt = default_training(all_events, training_weight, all_events_class, estimators=400)
    
    # Create a thing of all the results
    return {tuple(training_list): calc_performance(bdt, test, training_variables = training_list)}
# Out:
# Overwriting get_training_performance.py

# %%
def all_but_one (vlist, number_to_drop = 1):
    '''Return vlist and vlist with each item removed
    
    Arguments:
        vlist - the source list or tuple
        number_to_drop - return a list that is len(vlist)-number_to_drop - all possible combinations
        
    Returns:
        A list of tuples that have len(vlist)-number_to_drop items.
    
    '''
    var_training_list = itertools.combinations(vlist, len(vlist)-number_to_drop)
    var_training_list = list(var_training_list) + [tuple(vlist)]
    return var_training_list

# %%
import get_training_performance
pool = mp.Pool(processes=10)

def unused_var(original_list, used_list):
    r = tuple(i for i in original_list if i not in used_list)
    r = r if len(r) != 0 else ('None',)
    return r

def calc_var_removal(all_events, training_list = default_training_variable_list):
    r_drop_first = pool.map(get_training_performance.do_training,
             [(all_events, tvar_list) for tvar_list in all_but_one(training_list)])

    one_dict = {}
    for kp in r_drop_first:
        one_dict.update(kp)

    return pd.DataFrame({unused_var(training_list, k):one_dict[k] for k in one_dict}).T

# %%
def remove_all_variables(all_events, training_list = variable_list):
    done = False
    count = 0
    rlist = []
    while not done:
        count = count + 1
        print ("Iteration #{0}".format(count))
        print ('  Training with variable list:')
        print ('  ' + str(training_list))
        result = calc_var_removal(all_events, training_list=training_list)
        result_sorted = result.sort_values("HSSSsqrtB")
        rlist = rlist + [result_sorted]
        print (result_sorted.HSSSsqrtB)
        last_var_name = result_sorted.index[-1][0]
        done = last_var_name == 'None'
        if not done:
            training_list = training_list - set([last_var_name])
    return rlist

# %%
# %%time
#r_drop_first = calc_var_removal(all_events)

# %%
#print (r_drop_first.sort_values("HSSSsqrtB").HSSSsqrtB)

# %%
# %%time
r = remove_all_variables(all_events, variable_list)

# %%
len(r)

# %%
r[-1]

# %%
r[-2]

# %% [markdown]
# # Look at high $\eta$ and low $\eta$ list

# %%
# %%time
r_low_high = remove_all_variables(all_events, variable_list - {'RPredictedLxy', 'RPredictedLz', 'PredictedLxy', 'PredictedLz'})

# %%
r_low_high[-1]

# %% [markdown]
# # Look at full $\eta$ range predictions

# %%
r_full = remove_all_variables(all_events,variable_list - {'RPredictedLxy', 'RPredictedLz',
       'PredictedLxyHighEta', 'PredictedLxyLowEta', 'PredictedLzHighEta', 'PredictedLzLowEta'})
# Out:
# Iteration #1
#   Training with variable list:
#   {'MaxTrackPt', 'BIBDeltaTimingM', 'JetWidth', 'NTracks', 'ShowerCenter', 'JetPt', 'SumPtOfAllTracks', 'PredictedLxy', 'FirstCellTiming', 'CalRatio', 'FirstClusterRadius', 'BIBDeltaTimingP', 'EnergyDensity', 'HadronicLayer1Fraction', 'JetLat', 'JetEta', 'PredictedLz', 'JetLong'}
# JetPt                     50.249124
# NTracks                   54.593897
# FirstCellTiming           54.704339
# None                      55.044332
# SumPtOfAllTracks          55.442738
# JetWidth                  55.583377
# EnergyDensity             57.226793
# BIBDeltaTimingM           57.291547
# HadronicLayer1Fraction    57.643480
# MaxTrackPt                57.821080
# ShowerCenter              57.992857
# CalRatio                  58.137792
# PredictedLz               58.466361
# JetLong                   58.804112
# FirstClusterRadius        59.001169
# PredictedLxy              59.163485
# BIBDeltaTimingP           59.544159
# JetEta                    60.052550
# JetLat                    60.609688
# Name: HSSSsqrtB, dtype: float64
# Iteration #2
#   Training with variable list:
#   {'MaxTrackPt', 'NTracks', 'ShowerCenter', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'BIBDeltaTimingM', 'JetWidth', 'PredictedLxy', 'CalRatio', 'BIBDeltaTimingP', 'EnergyDensity', 'PredictedLz', 'FirstCellTiming', 'SumPtOfAllTracks', 'JetPt'}
# FirstCellTiming           53.338680
# JetPt                     54.023882
# BIBDeltaTimingP           54.333988
# JetWidth                  54.970791
# NTracks                   55.387733
# SumPtOfAllTracks          55.708445
# None                      56.797119
# CalRatio                  57.514960
# ShowerCenter              57.689985
# PredictedLz               58.475468
# FirstClusterRadius        58.620996
# MaxTrackPt                58.653248
# JetEta                    58.720684
# EnergyDensity             59.009905
# HadronicLayer1Fraction    59.071209
# BIBDeltaTimingM           59.298828
# JetLong                   59.596154
# PredictedLxy              61.608725
# Name: HSSSsqrtB, dtype: float64
# Iteration #3
#   Training with variable list:
#   {'MaxTrackPt', 'NTracks', 'ShowerCenter', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'BIBDeltaTimingM', 'JetWidth', 'SumPtOfAllTracks', 'CalRatio', 'BIBDeltaTimingP', 'EnergyDensity', 'FirstCellTiming', 'PredictedLz', 'JetPt'}
# JetPt                     49.486537
# JetWidth                  53.151157
# FirstClusterRadius        57.004517
# JetEta                    57.870582
# ShowerCenter              58.696307
# SumPtOfAllTracks          58.711170
# CalRatio                  59.084228
# EnergyDensity             60.401249
# JetLong                   60.649873
# MaxTrackPt                60.726551
# BIBDeltaTimingM           60.896772
# HadronicLayer1Fraction    60.957947
# PredictedLz               61.712820
# None                      62.583023
# BIBDeltaTimingP           62.918206
# NTracks                   63.888624
# FirstCellTiming           64.321961
# Name: HSSSsqrtB, dtype: float64
# Iteration #4
#   Training with variable list:
#   {'MaxTrackPt', 'NTracks', 'ShowerCenter', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'BIBDeltaTimingM', 'JetWidth', 'CalRatio', 'BIBDeltaTimingP', 'EnergyDensity', 'PredictedLz', 'SumPtOfAllTracks', 'JetPt'}
# JetPt                     50.000969
# HadronicLayer1Fraction    53.635038
# BIBDeltaTimingP           54.189067
# MaxTrackPt                56.020701
# NTracks                   56.678867
# JetLong                   56.723074
# PredictedLz               56.830804
# JetEta                    56.847589
# BIBDeltaTimingM           57.356214
# JetWidth                  57.450802
# FirstClusterRadius        58.091657
# EnergyDensity             59.094368
# CalRatio                  59.408388
# ShowerCenter              60.259610
# SumPtOfAllTracks          60.486814
# None                      61.115437
# Name: HSSSsqrtB, dtype: float64

# %%
for index, r in enumerate(r_full):
    print("Iteration {0}:".format(index))
    print("==============")
    print(list(r.index.levels[0]))
    print(r.HSSSsqrtB)
    print("")
# Out:
# Iteration 0:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstCellTiming', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLat', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLxy', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# JetPt                     50.249124
# NTracks                   54.593897
# FirstCellTiming           54.704339
# None                      55.044332
# SumPtOfAllTracks          55.442738
# JetWidth                  55.583377
# EnergyDensity             57.226793
# BIBDeltaTimingM           57.291547
# HadronicLayer1Fraction    57.643480
# MaxTrackPt                57.821080
# ShowerCenter              57.992857
# CalRatio                  58.137792
# PredictedLz               58.466361
# JetLong                   58.804112
# FirstClusterRadius        59.001169
# PredictedLxy              59.163485
# BIBDeltaTimingP           59.544159
# JetEta                    60.052550
# JetLat                    60.609688
# Name: HSSSsqrtB, dtype: float64
#
# Iteration 1:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstCellTiming', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLxy', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# FirstCellTiming           53.338680
# JetPt                     54.023882
# BIBDeltaTimingP           54.333988
# JetWidth                  54.970791
# NTracks                   55.387733
# SumPtOfAllTracks          55.708445
# None                      56.797119
# CalRatio                  57.514960
# ShowerCenter              57.689985
# PredictedLz               58.475468
# FirstClusterRadius        58.620996
# MaxTrackPt                58.653248
# JetEta                    58.720684
# EnergyDensity             59.009905
# HadronicLayer1Fraction    59.071209
# BIBDeltaTimingM           59.298828
# JetLong                   59.596154
# PredictedLxy              61.608725
# Name: HSSSsqrtB, dtype: float64
#
# Iteration 2:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstCellTiming', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# JetPt                     49.486537
# JetWidth                  53.151157
# FirstClusterRadius        57.004517
# JetEta                    57.870582
# ShowerCenter              58.696307
# SumPtOfAllTracks          58.711170
# CalRatio                  59.084228
# EnergyDensity             60.401249
# JetLong                   60.649873
# MaxTrackPt                60.726551
# BIBDeltaTimingM           60.896772
# HadronicLayer1Fraction    60.957947
# PredictedLz               61.712820
# None                      62.583023
# BIBDeltaTimingP           62.918206
# NTracks                   63.888624
# FirstCellTiming           64.321961
# Name: HSSSsqrtB, dtype: float64
#
# Iteration 3:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# JetPt                     50.000969
# HadronicLayer1Fraction    53.635038
# BIBDeltaTimingP           54.189067
# MaxTrackPt                56.020701
# NTracks                   56.678867
# JetLong                   56.723074
# PredictedLz               56.830804
# JetEta                    56.847589
# BIBDeltaTimingM           57.356214
# JetWidth                  57.450802
# FirstClusterRadius        58.091657
# EnergyDensity             59.094368
# CalRatio                  59.408388
# ShowerCenter              60.259610
# SumPtOfAllTracks          60.486814
# None                      61.115437
# Name: HSSSsqrtB, dtype: float64

# %%
r_full[0].columns
# Out:
# Index(['BIBBack', 'BIBEff', 'BIBSsqrtB', 'BIBTotalCount', 'BIBTotalWeight',
#        'BIBinBIB', 'BIBinHSS', 'BIBinMJ', 'HSSBack', 'HSSEff', 'HSSSsqrtB',
#        'HSSTotalCount', 'HSSTotalWeight', 'HSSinBIB', 'HSSinHSS', 'HSSinMJ',
#        'MJBack', 'MJEff', 'MJSsqrtB', 'MJTotalCount', 'MJTotalWeight',
#        'MJinBIB', 'MJinHSS', 'MJinMJ'],
#       dtype='object')

# %%
def plot_one(df_list, name):
    values = [float(df[name]['None']) for df in df_list]
    
    plt.plot(values)
    plt.xlabel(name)
    plt.show()
    
for c in r_full[0].columns:
    plot_one(r_full, c)

# %% [markdown]
# # Using original Rachel $L_{xy}$ and $L_{z}$ predictions

# %%
r_rachel = remove_all_variables(all_events,variable_list - {'PredictedLxy', 'PredictedLz',
       'PredictedLxyHighEta', 'PredictedLxyLowEta', 'PredictedLzHighEta', 'PredictedLzLowEta'})
# Out:
# Iteration #1
#   Training with variable list:
#   {'MaxTrackPt', 'BIBDeltaTimingM', 'JetWidth', 'NTracks', 'ShowerCenter', 'JetPt', 'FirstCellTiming', 'CalRatio', 'FirstClusterRadius', 'RPredictedLxy', 'BIBDeltaTimingP', 'EnergyDensity', 'HadronicLayer1Fraction', 'JetLat', 'RPredictedLz', 'JetEta', 'SumPtOfAllTracks', 'JetLong'}
# JetPt                     49.249605
# BIBDeltaTimingM           55.222203
# CalRatio                  56.233045
# FirstCellTiming           56.577485
# HadronicLayer1Fraction    56.596977
# NTracks                   56.879254
# SumPtOfAllTracks          57.027104
# MaxTrackPt                57.976496
# RPredictedLz              58.379349
# EnergyDensity             58.477199
# FirstClusterRadius        58.638382
# JetLat                    58.795543
# JetEta                    58.825268
# JetWidth                  58.928215
# ShowerCenter              59.630521
# JetLong                   62.691327
# None                      62.984026
# BIBDeltaTimingP           63.170210
# RPredictedLxy             64.330283
# Name: HSSSsqrtB, dtype: float64
# Iteration #2
#   Training with variable list:
#   {'MaxTrackPt', 'NTracks', 'ShowerCenter', 'FirstClusterRadius', 'JetLat', 'RPredictedLz', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'BIBDeltaTimingM', 'JetWidth', 'CalRatio', 'BIBDeltaTimingP', 'EnergyDensity', 'FirstCellTiming', 'SumPtOfAllTracks', 'JetPt'}
# JetPt                     49.264421
# JetWidth                  55.256160
# JetEta                    58.239615
# RPredictedLz              59.222376
# FirstCellTiming           59.837064
# FirstClusterRadius        60.800493
# SumPtOfAllTracks          61.159517
# HadronicLayer1Fraction    61.550436
# BIBDeltaTimingP           61.691334
# NTracks                   63.167487
# None                      63.322560
# CalRatio                  63.386712
# JetLong                   63.655435
# MaxTrackPt                63.711917
# EnergyDensity             64.055226
# ShowerCenter              64.090890
# JetLat                    65.391533
# BIBDeltaTimingM           66.632483
# Name: HSSSsqrtB, dtype: float64
# Iteration #3
#   Training with variable list:
#   {'MaxTrackPt', 'NTracks', 'ShowerCenter', 'FirstClusterRadius', 'JetLat', 'RPredictedLz', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetWidth', 'CalRatio', 'BIBDeltaTimingP', 'EnergyDensity', 'FirstCellTiming', 'SumPtOfAllTracks', 'JetPt'}
# JetPt                     50.718003
# JetWidth                  55.203882
# CalRatio                  57.256054
# JetEta                    58.603682
# RPredictedLz              58.969307
# ShowerCenter              60.651046
# FirstCellTiming           60.961359
# SumPtOfAllTracks          61.203449
# NTracks                   61.456472
# FirstClusterRadius        61.656067
# HadronicLayer1Fraction    61.713657
# MaxTrackPt                62.582360
# JetLong                   62.775161
# EnergyDensity             63.305050
# BIBDeltaTimingP           64.153189
# JetLat                    65.099903
# None                      65.128495
# Name: HSSSsqrtB, dtype: float64

# %%
for index, r in enumerate(r_full):
    print("Iteration {0}:".format(index))
    print("==============")
    print(list(r.index.levels[0]))
    print(r.HSSSsqrtB)
    print("")
# Out:
# Iteration 0:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstCellTiming', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLat', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLxy', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# JetPt                     50.249124
# NTracks                   54.593897
# FirstCellTiming           54.704339
# None                      55.044332
# SumPtOfAllTracks          55.442738
# JetWidth                  55.583377
# EnergyDensity             57.226793
# BIBDeltaTimingM           57.291547
# HadronicLayer1Fraction    57.643480
# MaxTrackPt                57.821080
# ShowerCenter              57.992857
# CalRatio                  58.137792
# PredictedLz               58.466361
# JetLong                   58.804112
# FirstClusterRadius        59.001169
# PredictedLxy              59.163485
# BIBDeltaTimingP           59.544159
# JetEta                    60.052550
# JetLat                    60.609688
# Name: HSSSsqrtB, dtype: float64
#
# Iteration 1:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstCellTiming', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLxy', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# FirstCellTiming           53.338680
# JetPt                     54.023882
# BIBDeltaTimingP           54.333988
# JetWidth                  54.970791
# NTracks                   55.387733
# SumPtOfAllTracks          55.708445
# None                      56.797119
# CalRatio                  57.514960
# ShowerCenter              57.689985
# PredictedLz               58.475468
# FirstClusterRadius        58.620996
# MaxTrackPt                58.653248
# JetEta                    58.720684
# EnergyDensity             59.009905
# HadronicLayer1Fraction    59.071209
# BIBDeltaTimingM           59.298828
# JetLong                   59.596154
# PredictedLxy              61.608725
# Name: HSSSsqrtB, dtype: float64
#
# Iteration 2:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstCellTiming', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# JetPt                     49.486537
# JetWidth                  53.151157
# FirstClusterRadius        57.004517
# JetEta                    57.870582
# ShowerCenter              58.696307
# SumPtOfAllTracks          58.711170
# CalRatio                  59.084228
# EnergyDensity             60.401249
# JetLong                   60.649873
# MaxTrackPt                60.726551
# BIBDeltaTimingM           60.896772
# HadronicLayer1Fraction    60.957947
# PredictedLz               61.712820
# None                      62.583023
# BIBDeltaTimingP           62.918206
# NTracks                   63.888624
# FirstCellTiming           64.321961
# Name: HSSSsqrtB, dtype: float64
#
# Iteration 3:
# ==============
# ['BIBDeltaTimingM', 'BIBDeltaTimingP', 'CalRatio', 'EnergyDensity', 'FirstClusterRadius', 'HadronicLayer1Fraction', 'JetEta', 'JetLong', 'JetPt', 'JetWidth', 'MaxTrackPt', 'NTracks', 'None', 'PredictedLz', 'ShowerCenter', 'SumPtOfAllTracks']
# JetPt                     50.000969
# HadronicLayer1Fraction    53.635038
# BIBDeltaTimingP           54.189067
# MaxTrackPt                56.020701
# NTracks                   56.678867
# JetLong                   56.723074
# PredictedLz               56.830804
# JetEta                    56.847589
# BIBDeltaTimingM           57.356214
# JetWidth                  57.450802
# FirstClusterRadius        58.091657
# EnergyDensity             59.094368
# CalRatio                  59.408388
# ShowerCenter              60.259610
# SumPtOfAllTracks          60.486814
# None                      61.115437
# Name: HSSSsqrtB, dtype: float64

# %%
def plot_one(df_list, name):
    values = [float(df[name]['None']) for df in df_list]
    
    plt.plot(values)
    plt.xlabel(name)
    plt.show()
    
for c in r_full[0].columns:
    plot_one(r_full, c)
